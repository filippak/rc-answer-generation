# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from transformers import AutoModel, AutoTokenizer, DataCollatorForTokenClassification, AutoModelForTokenClassification, TrainingArguments, Trainer
import torch
import torch.nn as nn
import pickle

# %%
CRA_TOKENS =  ['[BGN]', '[END]']
tokenizer = AutoTokenizer.from_pretrained('KB/bert-base-swedish-cased')
num_added_toks = tokenizer.add_tokens(CRA_TOKENS)
print('Added ', num_added_toks, 'tokens')
# Out:
# Added  2 tokens

# %%
model = torch.load('../results/model_CRA_5_epochs_weighted_loss.pkl')
with open(r'../data/CRA/tokenized_CRA_data_eval.pkl', "rb") as input_file:
    test_data = pickle.load(input_file)
tokens = tokenizer.convert_ids_to_tokens(test_data[0]["input_ids"])
print(tokens)
dec = tokenizer.decode(test_data[0]["input_ids"])
print(dec)
# Out:
# ['[CLS]', 'Eget', 'företag', 'Efter', 'beslut', 'Beslutet', 'skickas', 'till', 'den', 'ambassad', 'eller', 'generalkonsul', '##at', 'som', 'du', 'valde', 'i', 'webb', '##ansökan', '.', '[BGN]', 'När', 'du', 'ska', 'hämta', 'ditt', 'beslut', 'ska', 'du', 'ta', 'med', 'ditt', 'pass', '.', '[END]', 'Du', 'kan', 'få', 'uppehåll', '##stillstånd', 'för', 'två', 'år', 'men', 'aldrig', 'längre', 'än', 'ditt', 'pass', 'är', 'giltigt', '.', 'Om', 'du', 'får', 'uppehåll', '##stillstånd', 'för', 'mer', 'än', 'tre', 'månader', 'får', 'du', 'ett', 'uppehåll', '##stillstånd', '##skort', '.', 'Kort', '##et', 'är', 'ett', 'bevis', 'på', 'att', 'du', 'har', 'tillstånd', 'att', 'vara', 'i', 'Sverige', 'och', 'innehåller', 'bland', 'annat', 'dina', 'fingeravtryck', 'och', 'foto', 'på', 'dig', '.', '[BGN]', 'Uppehåll', '##stillstånd', '##skort', '##et', 'tillverkas', 'i', 'samband', 'med', 'att', 'beslutet', 'fattas', ',', 'dock', 'tidigast', 'tre', 'månader', 'innan', 'uppehåll', '##stillståndet', 'börjar', 'gälla', '.', '[END]', 'Det', 'går', 'inte', 'att', 'skynda', 'på', 'tillverkningen', 'eller', 'leveransen', 'av', 'kortet', '.', 'När', 'uppehåll', '##stillstånd', '##skort', '##et', 'är', 'klart', 'kommer', 'ambassaden', 'eller', 'generalkonsul', '##atet', 'att', 'lämna', 'ut', 'eller', 'skicka', 'det', 'färdiga', 'kortet', 'till', 'dig', '.', '[BGN]', 'Det', 'kan', 'ta', 'upp', 'till', 'fyra', 'veckor', 'att', 'tillverka', 'och', 'leverera', 'kortet', 'till', 'ambassaden', 'eller', 'generalkonsul', '##atet', 'efter', 'att', 'du', 'har', 'fått', 'ditt', 'beslut', '.', '[END]', 'När', 'du', 'reser', 'in', 'i', 'Sverige', 'måste', 'du', 'visa', 'upp', 'uppehåll', '##stillstånd', '##skort', '##et', 'tillsammans', 'med', 'ett', 'giltigt', 'pass', '.', 'Om', 'du', 'kan', 'resa', 'till', 'Sverige', 'utan', 'visum', 'bör', 'du', 'kunna', 'visa', 'upp', 'en', 'kopia', 'av', 'beslutet', 'när', 'du', 'reser', 'in', '.', 'Så', 'snart', 'du', 'kan', 'efter', 'att', 'du', 'har', 'kommit', 'till', 'Sverige', 'ska', 'du', 'boka', 'tid', 'på', 'Migration', '##sverket', 'för', 'att', 'lämna', 'fingeravtryck', 'och', 'bli', 'fotografera', '##d', '.', 'När', 'ditt', 'uppehåll', '##stillstånd', '##skort', 'är', 'klart', 'kommer', 'det', 'att', 'skickas', 'till', 'din', 'adress', 'i', 'Sverige', '.', 'Viktigt', 'om', 'försäkring', 'Om', 'du', 'behöver', 'söka', 'vård', 'i', 'Sverige', 'kan', 'du', 'behöva', 'betala', 'för', 'vården', 'själv', 'om', 'du', 'inte', 'är', 'folkbok', '##förd', 'i', 'Sverige', 'och', 'inte', 'har', 'ett', 'svenskt', 'personnummer', '.', 'Om', 'du', 'blir', 'folkbok', '##förd', 'kan', 'du', 'även', 'bli', 'inskr', '##iven', 'hos', 'Försäkring', '##skassan', 'och', 'omfattas', 'av', 'den', 'svenska', 'social', '##försäkringen', '.', 'För', 'att', 'bli', 'folkbok', '##förd', 'och', 'få', 'ett', 'svenskt', 'personnummer', 'krävs', 'i', 'regel', 'att', 'du', 'har', 'beviljats', 'minst', 'ett', 'års', 'uppehåll', '##stillstånd', 'i', 'Sverige', 'och', 'att', 'du', 'planerar', 'att', 'bo', 'här', 'i', 'ett', 'år', 'eller', 'längre', '.', 'Du', 'bör', 'därför', 'folkbok', '##föra', 'dig', 'så', 'snart', 'som', 'möjligt', 'efter', 'att', 'du', 'har', 'flyttat', 'till', 'Sverige', '.', '[SEP]']
# [CLS] Eget företag Efter beslut Beslutet skickas till den ambassad eller generalkonsulat som du valde i webbansökan. [BGN] När du ska hämta ditt beslut ska du ta med ditt pass. [END] Du kan få uppehållstillstånd för två år men aldrig längre än ditt pass är giltigt. Om du får uppehållstillstånd för mer än tre månader får du ett uppehållstillståndskort. Kortet är ett bevis på att du har tillstånd att vara i Sverige och innehåller bland annat dina fingeravtryck och foto på dig. [BGN] Uppehållstillståndskortet tillverkas i samband med att beslutet fattas, dock tidigast tre månader innan uppehållstillståndet börjar gälla. [END] Det går inte att skynda på tillverkningen eller leveransen av kortet. När uppehållstillståndskortet är klart kommer ambassaden eller generalkonsulatet att lämna ut eller skicka det färdiga kortet till dig. [BGN] Det kan ta upp till fyra veckor att tillverka och leverera kortet till ambassaden eller generalkonsulatet efter att du har fått ditt beslut. [END] När du reser in i Sverige måste du visa upp uppehållstillståndskortet tillsammans med ett giltigt pass. Om du kan resa till Sverige utan visum bör du kunna visa upp en kopia av beslutet när du reser in. Så snart du kan efter att du har kommit till Sverige ska du boka tid på Migrationsverket för att lämna fingeravtryck och bli fotograferad. När ditt uppehållstillståndskort är klart kommer det att skickas till din adress i Sverige. Viktigt om försäkring Om du behöver söka vård i Sverige kan du behöva betala för vården själv om du inte är folkbokförd i Sverige och inte har ett svenskt personnummer. Om du blir folkbokförd kan du även bli inskriven hos Försäkringskassan och omfattas av den svenska socialförsäkringen. För att bli folkbokförd och få ett svenskt personnummer krävs i regel att du har beviljats minst ett års uppehållstillstånd i Sverige och att du planerar att bo här i ett år eller längre. Du bör därför folkbokföra dig så snart som möjligt efter att du har flyttat till Sverige. [SEP]

# %%
def get_predicted_answers(output, tokens):
    extracted_answers = []
    last_idx = None
    current_answer = ''
    for idx, label in enumerate(output):
        if label == 2 and len(current_answer) > 0: # add to existing answer, only if there is an existing answer..
            current_answer += tokens[idx] +' '
        elif label == 1:
            # append the current answer
            if len(current_answer) > 0:
                extracted_answers.append(current_answer)
            current_answer = tokens[idx] +' '
        elif len(current_answer) > 0:
            extracted_answers.append(current_answer)
            current_answer = ''
    print(extracted_answers)

# %%
# Output class
# https://huggingface.co/docs/transformers/main_classes/output#transformers.modeling_tf_outputs.TFTokenClassifierOutput

model.eval()
test_input = []
test_labels = []
test_attn = []
token_type_ids = []
for i in range(len(test_data)):
    test_input.append(test_data[i]['input_ids'])
    test_labels.append(test_data[i]['labels'])
    test_attn.append(test_data[i]['attention_mask'])
    token_type_ids.append(test_data[i]['token_type_ids'])

print(len(test_input))
print(len(test_labels))
print(len(test_attn))
num_correct = 0
num_predicted = 0
num_pos_data = 0
for i in range(len(test_data)):
    output = model(torch.tensor([test_data[i]['input_ids']]), attention_mask=torch.tensor([test_data[i]['attention_mask']]), token_type_ids=torch.tensor([test_data[i]['token_type_ids']]), labels=torch.tensor([test_data[i]['labels']]))
    print('test idx: ', i)
    print('instance loss: ', output.loss)
    # print(output.logits)
    m = nn.Softmax(dim=2)
    max = m(output.logits)
    out = torch.argmax(max, dim=2)
    # print(max)
    # print('Output: ', out[0])
    # print('labels length: ', len(test_data[i]['labels']))
    # print('Labels: ', test_data[i]['labels'])
    tokens = tokenizer.convert_ids_to_tokens(test_data[i]["input_ids"])
    true_labels = test_data[i]['labels']
    # print(tokens)
    get_predicted_answers(true_labels, tokens) # print the correct answer
    get_predicted_answers(out[0], tokens)
    for idx, pred_label in enumerate(out[0]):
        true_label = true_labels[idx]
        if true_label > 0:
            num_pos_data += 1
        if pred_label > 0:
            # print('label: ', pred_label)
            # print('token: ', tokens[idx])
            num_predicted += 1
            if pred_label == true_label:
                num_correct += 1

# calculate precision and recall
pr = num_correct/num_predicted
rec = num_correct/num_pos_data
print('precision: ', pr)
print('recall: ', rec)
# Out:
# 295
# 295
# 295
# test idx:  0
# instance loss:  tensor(0.6612, grad_fn=<NllLossBackward>)
# ['ditt pass ']
# ['till ', 'den ambassad eller generalkonsul ##at som du valde i ', 'webb ##ansökan ', 'När du ska hämta ditt beslut ', 'ska ', 'ta ', 'med ', 'ditt pass . ', 'två år ', 'ett ', 'dina ', 'fingeravtryck och ', 'foto på dig ', 'Uppehåll ', '##stillstånd ', '##skort ', '##et ', 'tillverkas ', 'i samband med att beslutet fattas , ', 'dock ', 'tidigast ', 'tre månader innan uppehåll ##stillståndet börjar gälla ', 'ta ', 'upp till ', 'fyra veckor ', 'att tillverka och leverera kortet ', 'till ambassaden eller generalkonsul ##atet efter att du har fått ditt beslut ']
# test idx:  1
# instance loss:  tensor(0.4665, grad_fn=<NllLossBackward>)
# ['föräldra ']
# ['Te ', '##ori ', 'för ', 'att ge eleverna en bred kunskap ', 'Bak ', '##ning och ', 'matlagning ', 'kunskaper ', 'närings ##lär ', 'hur ', 'livsmedels ##hantering ', 'ekonomi och ', 'lära ', 'hur ', 'olika redskap i hemmet används på ett säkert sätt samt ', 'olika metoder för ', 'tvätt och rengöring ', 'Hem ', 'i ', 'konsument ##ekonomi ', 'hur man får pengarna att räcka ', 'läraren ', 'undervisning ', 'mycket ', 'föräldra ##möten och ', 'kompetens ##utveckling ']
# test idx:  2
# instance loss:  tensor(0.6720, grad_fn=<NllLossBackward>)
# ['personuppgifter ']
# ['praktik ', 'Om ', 'ansöka ', 'om ', 'uppehåll ##stillstånd för ', 'besök ', 'dig ', 'att du har pengar för den tid du ska besöka Sverige ', 'kopior av de sidor i ditt pass som visar ', 'personuppgifter ', 'foto , ', 'namn ##teckning , ', 'pass ##nummer , ', 'utfärda ##nd ##eland , ', 'giltighet ##stid ', 'om du har tillstånd att bo i andra länder än ditt hemland ', 'retur ##biljett ', 'dokument som visar ', 'att du har pengar för att köpa en biljett ', '1640 ', '165 ', '238 ', '239 ']
# test idx:  3
# instance loss:  tensor(0.5968, grad_fn=<NllLossBackward>)
# ['att det blir tal om personal ']
# ['Åtgärder ', 'olycksfall ', 'Tid ', 'när åtgärderna ska vara genomförda ', 'Vem som ska se till att åtgärderna genomförs i tid ', 'Arbetsgivar ', 'kontrollera ', 'att ', 'Risk ', 'Om ', 'fullmäktige ', 'kirurg avdelningen eller ', 'barn - och ungdoms ##nämnden ', 'påverkar ', 'detta ', 'verksamheten ', 'Den ', 'minskade budgeten ', 'innebär ', 'att det blir tal om personal ##ned ##dragningar ', 'Innan ', 'utökning , ', 'förändrade uppdrag , minskade anslag ', 'på ', 'Förs ##kol ##an ', 'Arbets ', 'kvarvarande ']
# test idx:  4
# instance loss:  tensor(0.5711, grad_fn=<NllLossBackward>)
# ['arbetsgivare ']
# ['co ', 'regler för ', 'hur personer som inte fyllt 18 år får arbeta ', 'Före ', 'riktar ', 'till ', 'arbetsgivare , ', 'uppdragsgivare , skol ##huvud ##män och praktik ##givare som låter minderåriga utföra arbete ', 'AF ', 'Boken ', 'uppdelad ', 'i ', 'två ', 'delar ', ', ', 'som ', 'handlar ', 'om ', 'arbetsmiljön i arbetslivet respektive skolan . ', '[BGN] ', 'Reglerna ', 'liknar ', 'varandra ', 'vissa skillnader ', 'Del ', 'om arbetslivet ', 'ger ', 'exempel från de branscher där det är vanligast att minderåriga arbetar ', 'detaljhandel ']
# test idx:  5
# instance loss:  tensor(2.0749, grad_fn=<NllLossBackward>)
# ['de fackliga organisationer ']
# ['6 kap ', 'när skydds ##ombud ##et gett dig en begäran om åtgärder kring arbetsmiljö eller arbetstider ', 'med stöd av arbetsmiljö ##lagen 6 kap 6 ##a § ', 'Skydd ', '##sombud ', '##et ', 'kan ', 'begära ', 'åtgärder i arbetsmiljön av dig ', 'med stöd av ', '6 kap . 6 ##a § arbetsmiljö ##lagen ', 'när det gäller arbetsmiljö ##frågor och ', '19 ##a § arbetstid ##slagen ', 'när det gäller mer ##tid , extra övertid och nöd ##fall ##söver ##tid ', 'Ett ', 'lokalt skydds ##ombud ', 'kan ', 'enbart ', 'begära ', 'åtgärder inom det egna skydds ##området ', 'Skydd ', '##sombud ', 'bara ', 'rätt ', '19 ##a § arbetstid ##slagen ', 'om arbetstid ##slagens regler inte ersatts av kollektivavtal ', 'Om reglerna har ersatts av ', 'kollektivavtal ', 'istället ', 'de fackliga organisationer ##na och arbetsgivaren som ska bevaka att avtalet följs ', 'skydds ##ombud eller ', 'Arbets ##miljö ##verket ', 'agera ']
# test idx:  6
# instance loss:  tensor(0.4645, grad_fn=<NllLossBackward>)
# ['arbetsplats ']
# ['samverka ', 'med arbetstagare och skydds ##ombud ', 'så ', 'att fler hjälps åt att upptäcka de risker som kan finnas i arbetsmiljön ', 'att ', 'arbetsmiljö ##frågor ', 'arbetsplats ', '##träff ', '##ar , ', 'med ##arbetar ##samtal och ', 'skydds ##kommitté ##möten ', 'att ', 'visar ', 'dokument ', 'Rutin ', 'för ', 'alla olika aktiviteter i SAM ', 'att ', 'att de kan samordnas med dessa ']
# test idx:  7
# instance loss:  tensor(0.4140, grad_fn=<NllLossBackward>)
# ['att ställa krav på arbetsmiljö redan vid upphandling ']
# ['motverka ', 'os ##und konkurrens i arbetslivet ', 'att ', 'ställa ', 'krav på ', 'arbetsmiljö ', 'arbets ##olyckor och ', 'anbud ', '[BGN] ', 'Du ', 'som är anbud ##sgivare och vill bli leverantör av tjänsten ', 'att ', 'motverka den os ##unda konkurrensen vid upphandling ##en ', 'genom ', 'att visa i anbud ##et ', 'att du är en ansvarstagande arbetsgivare . ', 'genom ', 'att ', 'att du följer ', 'Arbets ##miljö ##verkets ']
# test idx:  8
# instance loss:  tensor(0.8449, grad_fn=<NllLossBackward>)
# ['tre år ']
# ['att du får ett nytt tidsbegränsat uppehåll ##stillstånd som gäller ', 'i ', 'två eller tre år ', 'om du har ', 'flykting ##status ( ', 'tre år ) eller status som alternativt skydds ##beh ##övande ( ', 'två år ) ', 'ett kortare tillstånd ', 'om du har tillstånd ', 'på grund av studier på gymnas ##ial nivå ', 'och du har mindre än två år kvar på din gymnasie ##utbildning ', 'uppehåll ', 'att du ']
# test idx:  9
# instance loss:  tensor(0.3931, grad_fn=<NllLossBackward>)
# ['att arbetstag ']
# ['att ', 'budgeter ', 'ett nytt ventilation ##ssystem ', 'omför ', '##delar ', 'nämnden ', 'troligen tillgängliga resurser ', 'Om ', 'nämnden ', 'att ', 'skjuta upp viss skol ##verksamhet ', 'låna eller ', 'hyra lämplig utrustning ', 'införa nya rutiner som ', 'förviss ', '##a ', 'i ']
# test idx:  10
# instance loss:  tensor(0.4464, grad_fn=<NllLossBackward>)
# ['tillstånd ']
# ['När vi har tagit emot din ansökan [END] ', 'Om du har lämnat in en ansökan om förlängning innan tiden för ditt tidigare tillstånd har gått ut ', 'har ', 'rätt att vara kvar i Sverige ', 'tills [END] [BGN] Migration ##sverket har fattat sitt beslut ']
# test idx:  11
# instance loss:  tensor(0.4272, grad_fn=<NllLossBackward>)
# ['beman ']
# ['Arbets ', 'beman ##ningsföretag ', 'ett ', 'ansvar ', 'speciella ', 'innan , ', '1 , 6 procent ', 'via ', 'ett ', 'beman ##ningsföretag ', 'Att ', 'på ', 'flera möjligheter till utveckling ', 'att de inte ska skada sig ', 'Arbets ', '##miljö ', 'för ', 'beman ##ningsföretag ##et och kund ##företaget ', 'ett ansvar ', 'arbetsgivare ', 'broschyren ', 'extern ', 'öppnas ', 'i nytt fönster ']
# test idx:  12
# instance loss:  tensor(0.1723, grad_fn=<NllLossBackward>)
# ['242 ']
# ['permanent ', 'räkna ', 'ihop dina inkomster ', 'från ', 'flera anställningar , ', 'från anställning och eget företag ', 'att du är ', 'att ', 'Förs ', '##äkra ', '##n om samlevnad ', 'blankett ', '242 ', '##0 ']
# test idx:  13
# instance loss:  tensor(0.5844, grad_fn=<NllLossBackward>)
# ['boka tid ']
# ['inte ', 'tillräckliga ', 'ett ', 'främling ##spass ', 'ett ', 'främling ##spass ', 'av ', 'Migration ##sverket ', 'Migration ', '##sverket ', 'kan ', 'inte ', 'heller ', 'utfärda ', 'främling ##spass till en person som befinner sig i sitt hemland ', 'Ansök ', 'främling ##spass ', 'ansöker ', 'ett främling ##spass ', 'genom ', 'att ', 'fylla i ', 'blankett ##en ', 'Ansökan om främling ##spass , ', 'nummer ', '1900 ##11 , och lämna in den ', 'vid ett personligt besök på någon av Migration ##sverkets tillstånd ##senheter ', 'Innan du ', 'besöker ', 'Migration ##sverket för att lämna in din ansökan ', 'ska ', 'boka tid ', 'boka ', 'en tid ', 'främling ##spass ']
# test idx:  14
# instance loss:  tensor(0.2011, grad_fn=<NllLossBackward>)
# ['massage ']
# ['att ', 'café ##verksamhet ', 'snickeri , ', 'konst eller ', 'dator ##kurser ', 'sinness ', '##ti ', '##mu ', '##ande ', 'aktiviteter ', 'bad , ', 'massage , ', 'musik ', 'sjukgymnast ##ik ', 'barn ', 'vistas ', 'barn ', 'vissa ', 'helger ']
# test idx:  15
# instance loss:  tensor(0.3117, grad_fn=<NllLossBackward>)
# ['städning ']
# ['Stöd ', '##assistent ', 'Stöd ', '##assistenter ', 'grupp ##boende , daglig verksamhet eller ', 'korttid ##shem för barn ', 'Inom ', 'grupp ', '##boenden ', 'om ', 'att stötta och hjälpa till ', 'vid vardagliga sysslor som ', 'matlagning och ', 'städning ', 'att ']
# test idx:  16
# instance loss:  tensor(0.5018, grad_fn=<NllLossBackward>)
# ['ett nytt uppehåll ']
# ['tillstånd för samma tid ', '13 månader ', 'ett nytt uppehåll ##stillstånd ', 'på ', 'två år ', 'Per ', 'två år ', 'överklaga ', 'inom ', 'tre veckor från den dag du fick beslutet ', 'Information ', 'om ', 'hur du gör ', 'finns ', 'i ditt beslut ', 'Om du har gett någon ', 'en fullmakt att företräda dig ', 'överklaga ', 'Barn under ', '18 år ', 'inte ', 'själva ', 'överklaga ', 'föräldrarna ']
# test idx:  17
# instance loss:  tensor(0.5016, grad_fn=<NllLossBackward>)
# ['konflikt ']
# ['inom ', 'arbetar ', 'på ', 'vårdcentral ##er , ', 'inom psykiatrin , skolan , kriminalvård ##en , idrotts ##världen , försvaret och ', 'inom arbetsliv och organisation ', 'egna ', 'Psyk ', '##ologen ', 'anpassar behandlingen till patientens behov ', 'Psyk ', 'på ', 'Psyk ', '##ologen ', 'kan ', 'hjälpa till ', 'att ', 'hantera konflikt - och kris ##situation ##er på arbetsplatser ']
# test idx:  18
# instance loss:  tensor(0.5679, grad_fn=<NllLossBackward>)
# ['grundade i forskning och bepröv ']
# ['Psyk ', 'Psyk ', 'på ', 'vårdcentral ##er ', 'inom ', 'inom arbetsliv och organisation ', 'Många ', 'psykologer ', 'är ', 'egna företagare ', 'Psyk ', 'gör ', 'fördjupa ', 'psykologiska tester ', 'för att mer detaljer ##at beskriva problem och ', 'ge ', 'mer genom ##arbetade förslag till åtgärder ', 'utredning ', 'förebyggande arbete ', 'psykologen ', 'stödja ', 'motivera ', 'arbetar ', 'med hjälp av ', 'olika psykologiska metoder som är grundade ', 'i ', 'forskning och bepröv ##ad erfarenhet ', 'på ', 'depression ', 'ångest ']
# test idx:  19
# instance loss:  tensor(0.5811, grad_fn=<NllLossBackward>)
# ['hälso ']
# ['att ', 'möta personen ##s behov av trygghet och välbefinnande ', 'vid ', 'undersökningar och behandlingar ', 'intervjuar ', 'sjuksköterskan personen ', 'kring den aktuella situationen och ', 'Som ', 'sjuksköterska ', 'arbetar ', 'förebyggande ', 'för ', 'att främja ', 'hälsa ', 'genom ', 'hälso ##upplysning och rådgivning ', 'att sätta dropp , ge injektion ##er , ', 'fördela medicin ']
# test idx:  20
# instance loss:  tensor(0.8814, grad_fn=<NllLossBackward>)
# ['bredare arbetsuppgifter ']
# ['På ', 'ett mindre företag ', 'har ', 'ofta ', 'bredare arbetsuppgifter ', 'på ', 'mer specialiserade ', 'att ', 'sköta ', 'underhåll av serv ##rar , ', 'infrastruktur , nätverk , system och applikationer ', 'Att ', 'lösa support ##ärenden , ', 'utföra installationer av applikationer , system och serv ##rar ', 'Drift ', '##tekniker ', 'beställa och ', 'koordin ', '##era underhåll ##stjänster ', 'i de fall man köper in dem av andra företag ', 'outs ##our ', 'drift ', 'i ', 'automatik ']
# test idx:  21
# instance loss:  tensor(0.6918, grad_fn=<NllLossBackward>)
# ['data ']
# ['IT ', 'säkerhets ##tekniker ', 'arbetar ', 'med ', 'att följa upp och administrera företagets IT - säkerhets ##system ', '[BGN] ', 'De ', 'övervaka ', '##r och ', 'kontrollerar ', 'så kallade ', 'brand ##väggar , ', 'dvs ', 'data ##program som förhindrar intrång i systemen ', 'IT ', 'säkerhets ', 'arbetar ', 'att göra riska ##nal ##yser samt ', 'utforma ##r , vidareutveckla ##r och inför säkerhets ##lösningar ', 'vara ', 'att göra ', 'tekniska granskning ##ar av säkerhets ##system ##en och utbilda kunder ', 'ändringar ']
# test idx:  22
# instance loss:  tensor(0.4443, grad_fn=<NllLossBackward>)
# ['att följa upp en praktik ']
# ['med ', 'både ', 'då de behöver rekrytera och mer förutsättning ##slöst ', 'för ', 'att informera och skapa ett kontaktnät ', 'kunskaper ', 'uppföljning ', 'att ', 'följa upp en praktik ##plats och se till att den ger mervärde till både arbetssökande och arbetsgivare ', 'att stödja den ', 'att uppfylla de ', 'att ']
# test idx:  23
# instance loss:  tensor(0.6709, grad_fn=<NllLossBackward>)
# ['arbetskraft ']
# ['[BGN] ', 'Arbetsuppgifter ', '[END] ', '[BGN] ', 'Arbets ', '##förmed ', '##laren ', '##s ', 'uppdrag ', 'är ', 'att ', 'via ', 'match ##ning samman ##föra arbetsgivare som söker arbetskraft med arbetssökande som söker arbete ', 'Match ', 'möten ', 'IT ', 'att ', 'följa upp en praktik ##plats ', 'se till att den ger mervärde till både arbetssökande och arbetsgivare ', 'ansvar ', 'att stödja den arbetssökande ', 'att uppfylla de villkor som ställs i arbetslöshets ##försäkringen och ', 'att tydlig ##göra vilka krav som ställs . ']
# test idx:  24
# instance loss:  tensor(0.4125, grad_fn=<NllLossBackward>)
# ['på Försäkring ']
# ['Social ', '##försäkring ', '##shand ', '##läggare ', 'De ', 'social ', '##försäkring ', '##shand ', '##läggare ', 'arbetar ', 'på ', 'Försäkring ##skassan ', 'en arbetslöshets ##kassa , ', 'A - kassa ', 'A ', 'på ', 'en bransch ', 'personligt ', 'sjukdom eller arbetslöshet ', 'På ', 'Försäkring ', '##skassan ', 'hjälper ', 'handläggare ##n ', 'kunder så att rätt person får rätt ersättning i rätt tid ']
# test idx:  25
# instance loss:  tensor(0.5001, grad_fn=<NllLossBackward>)
# ['att strålning ']
# ['att strålning ##en måste göra mer nytta än ', 'hud ', 'exponering för ', 'ult ##rav ##iol ##ett strålning ( ', 'U ##V - strålning ', 'För ', 'att vända trenden ', 'måste ', 'människors exponering ', 'minska , ', 'både ', 'vid sola ##nd ##e utomhus och ', 'i sola ##rier ', 'förändring ', 'utseende ', 'ett slut ', 'I dagsläget ', 'två identifierade områden där ', 'forskning gett upphov till misstanke om skadliga hälso ##effekter vid exponering för elektrom ##agne ##tis ##ka fält ', 'Strål ']
# test idx:  26
# instance loss:  tensor(0.5643, grad_fn=<NllLossBackward>)
# ['uran ']
# ['från ', 'naturligt radioaktiva ämnen i marken och i vår egen kropp ', 'utvecklat ', 'metoder ', 'att skapa och dra nytta av strålning ##ens egenskaper ', 'inom forskning , sjukvård och industri ', 'genom ', 'att använda ', 'röntgen ##teknik och ', 'genom ', 'att använda ', 'uran i kärnkraft ##sre ##akt ##orer ', '[BGN] ', 'Strål ', 'i ', 'elektrom ##agne ##tis ##ka fält ', 'som ', 'radio ##våg ##or från ', 'mobiltelefoner och ', 'magnet ##fält från kraft ##ledningar ', 'Strål ', '##ning ', 'till nytta ', 'att de skadliga effekterna av strålning på människa och miljö ', 'all verksamhet med strålning ', 'att strålning ##en måste göra mer nytta än skada ', 'hands ']
# test idx:  27
# instance loss:  tensor(0.3018, grad_fn=<NllLossBackward>)
# ['nål ']
# ['att ', 'att ', 'tatu ', 'arbetar ', 'med ', 'eld ##rivna tatu ##erings ##maskiner utrustade med tuber och nål ##ar i olika storlekar ', 'Nå ', 'dopp ', 'i ', 'färg ', 'penn ']
# test idx:  28
# instance loss:  tensor(0.2696, grad_fn=<NllLossBackward>)
# ['beställer varor ']
# ['inom hotell - och restaurang ##näringen ', 'Hy ', '##gie ##n ', 'i ', '[BGN] ', 'Arbetsplatsen ', 'vara ', 'ren och hygien ##isk ', 'livsmedel ', 'hanteras på ett korrekt sätt ', 'arbetsledare ', 'En ', 'kall ', '##sk ', '##änks ', '##chef ', 'beställer ', 'varor och ', 'ha ', 'hand om planeringen av matsedel ']
# test idx:  29
# instance loss:  tensor(0.9816, grad_fn=<NllLossBackward>)
# ['att du har egna pengar för din försörjning ']
# ['på gymnasium och folkhögskola ', 'Innan ', 'Kontroll ', '##era ', 'att informationen ', 'Viktiga ', 'uppgifter ', 'ditt namn ', 'framgå ', '##ningsb ', '##ked som ', 'visar ', 'att du är antagen till studier på heltid ', 'kopia på ', 'dokument som visar ', 'att du har en heltäckande sjukförsäkring som gäller i Sverige ', 'Försäkring ', 'gälla ', 'för ', 'hela den tid du ska vara i Sverige ', 'täcka ', 'kostnader för akut och annan läkarvård , ', 'tandvård och sjukhus ##vistelse ', '[BGN] ', 'Den ', 'ska ', 'täcka ', 'kostnader för ', 'hemt ##ransport av ', 'medicinska skäl ', 'konto ', '##ut ', '##drag från din bank som styrke ##r ', 'att du har egna pengar för din försörjning ', 'Kont ', '##out ', 'dat ##erat ', 'i anslutning till ansöknings ##till ##fälle ##t ', 'dokument ', 'att du har fått ', 'intyg ', 'att du kommer att få fick ', '105 ']
# test idx:  30
# instance loss:  tensor(0.6571, grad_fn=<NllLossBackward>)
# ['att du är antagen till studier på heltid ']
# ['en kopia av ', 'skicka ', 'din ansökan ', 'skicka ', 'med ', '[BGN] ', 'kopior av de sidor i ditt pass som visar ', 'personuppgifter , ', 'foto , ', 'namn ##teckning , pass ##nummer , utfärda ##nd ##eland , giltighet ##stid ', 'om du har tillstånd att bo i andra länder än ditt hemland ', 'antag ', '##ningsb ', '##es ', '##ked ', 'att du är antagen till ', 'kopia på ', 'dokument ', 'visar ', 'att du har en heltäckande sjukförsäkring som gäller i Sverige ', 'Försäkring ', 'för ', 'hela den tid du ska vara i ', 'att du kommer att få fick ', '105 ##0 ']
# test idx:  31
# instance loss:  tensor(0.5641, grad_fn=<NllLossBackward>)
# ['flyg ']
# ['Flyg ', 'flyg ##tekniker ', 'När översyn ##en är färdig ', 'kontrollerar ', 'flyg ##tekniker ##n ', 'att arbetet är korrekt utfört ', '[BGN] ', 'Varje åtgärd ', 'dokumentera ', '##s ', 'in i minsta detalj ', 'så ', 'att det i efterhand går att se ', 'vilken tekniker / mekaniker som utfört vilket arbetsm ##oment ', 'flyg ', 'certif ', 'självständigt ', 'i grupp ', 'att man ', 'rot ##erar mellan olika arbetsuppgifter ']
# test idx:  32
# instance loss:  tensor(0.6200, grad_fn=<NllLossBackward>)
# ['sköter installation och underhåll av flygplan ']
# ['flyg ', 'ta ', 'flera veckor ', 'arbetar ', 'efter ', 'man ##ual ##er och föreskrifter som ', 'beskriver ', 'vad som ska göras och på vilket sätt ', 'ser ', 'över ', 'motor , rod ##er och bränsle ##system ', 'byter ', 'När översyn ##en är färdig ', 'kontrollerar ', 'flyg ##tekniker ##n ', 'att arbetet är korrekt utfört ', 'dokumentera ', 'Flyg ', '##mekan ', '##iker ', 'flyg ##tekniker ', 'arbetar ', 'nära flygplans ##elekt ##riker ', 'sköter ', 'installation och underhåll av flygplan ##ens kab ##lage och els ##ystem ']
# test idx:  33
# instance loss:  tensor(0.5850, grad_fn=<NllLossBackward>)
# ['flyg ']
# ['hos ', 'inom flyg ##industrin ', 'inom fristående flyg ##tekniska verkstäder ', 'flyg ##mekan ##iker ', 'flyg ', 'att tekniker ', 'har ', 'längre utbildning och får ta ett större ansvar i arbetet ', 'flera veckor ', 'Vid ', 'översyn ', 'arbetar ', 'efter ', 'man ##ual ##er och föreskrifter som ', 'beskriver ', 'vad som ska göras och på vilket sätt ', 'ser ', 'över ', 'motor , ']
# test idx:  34
# instance loss:  tensor(0.1721, grad_fn=<NllLossBackward>)
# ['uppehåll ']
# ['ansöka ', 'om ', 'uppehåll ##stillstånd för besök ', 'Uppdrag ', '##sutbildning i Sverige på ett universitet eller högskola ', 'antagen ', 'heltid ']
# test idx:  35
# instance loss:  tensor(0.4355, grad_fn=<NllLossBackward>)
# ['att ta kortare eller längre uppdrag som egen ']
# ['Cop ', 'på ', 'kommunikations ##byrå ##er och ', 'på ', 'inh ', 'att ', 'frilans ', 'att ta ', 'kortare eller längre uppdrag ', 'som egen ##företagare eller ', 'som tillfälligt anställd ', 'kunskap om ', 'om ', 'Allmän ', '##bildning och ', 'ett samhälls ##intresse ', 'liksom ', 'att kunna formulera sig kärn ##fullt i text ']
# test idx:  36
# instance loss:  tensor(0.6490, grad_fn=<NllLossBackward>)
# ['att borr ']
# ['Bor ', '##rn ##ing av ', 'dricksvatten ##brunn ##ar ', 'Bor ', '##rn ##ing av energi ##brunn ##ar ', 'berg ##värme ', 'entreprenad ', 'om ', 'att borr ##a grund ##läggning inom ett anläggnings ##projekt ', 'De ', 'som ', 'med ', 'prospekt ##ering ', 'tar ', 'fram ', 'borr ##kär ##nor ', 'för ', 'att prospekt ##erings ##företag ska kunna analysera innehållet i marken ', 'använder ', 'brunn ', '##sbor ##rare ', 'mobila ', 'borr ##igga ##r och ', 'olika typer av ', 'borr ##verktyg ', 'att ']
# test idx:  37
# instance loss:  tensor(0.8939, grad_fn=<NllLossBackward>)
# ['kund ']
# ['Bor ', '##rn ##ing av ', 'dricksvatten ##brunn ##ar ', 'Bor ', '##rn ', 'berg ', 'hitta lösningar ', 'Ibland ', 'gör ', 'man ', 'kund ##besök ', 'för ', 'att undersöka marken där borr ##ningen ska utföras ', 'Energi ', 'att borr ##a grund ##läggning inom ett anläggnings ##projekt ', 'att ', 'Kunskaper ', 'i ', 'svets ##ning , ', 'mekanik och ', 'hydra ##uli ##k ', 'Arbets ', 'borr ', 'utomhus ', 'i olika typer av väder ##förhållanden ', 'Brunn ', '##sbor ', 'arbetar ', 'på företag som täcker stora geografiska områden ', 'att man ibland behöver arbeta utanför hemorten ']
# test idx:  38
# instance loss:  tensor(0.6920, grad_fn=<NllLossBackward>)
# ['berg ']
# ['Brunn ', '##sbor ', 'arbetar ', 'inom ', 'tre ', 'Bor ', '##rn ', '##ing av ', 'dricksvatten ##brunn ##ar ', 'Bor ', '##rn ', 'berg ', 'Entreprenad ', 'hitta lösningar ', 'Ibland ', 'gör ', 'man ', 'kund ##besök ', 'för ', 'att undersöka marken där borr ##ningen ska utföras ', 'Energi ##borr ##ning ', 'det ', 'ökat ', 'snabbast ', 'de senaste åren ', 'Energi ##borr ##ning ', 'att borr ##a mycket djupa hål i marken för att ', 'entreprenad ', 'att borr ##a grund ##läggning inom ett anläggnings ##projekt ']
# test idx:  39
# instance loss:  tensor(0.5382, grad_fn=<NllLossBackward>)
# ['en teknisk beskrivning ']
# ['styrning och övervakning av säkerheten ', 'Larm ', 'ansluta larmet till kundernas nätverk ', 'för ', 'att öka bekvämlighet ##en och möjligheten att styra andra system ', 'Larm ', 'efter ', 'att ', 'ge ', 'råd ', 'hjälpa ', 'Larm ', '##n ', 'gör ', 'en teknisk beskrivning av installation ##en , ', 'för ', 'att andra ska kunna se hur den är gjord ', 'överläm ', 'att ', 'utbilda ', 'användare av ', 'larm - och ', 'handha ', 'instruktioner ']
# test idx:  40
# instance loss:  tensor(0.4551, grad_fn=<NllLossBackward>)
# ['ansluta larmet till kundernas nätverk ']
# ['Arbetsuppgifter ', 'Larm ', '- och säkerhets ', '##tekniker ', 'installera ', '##r , ', 'drift ', '##sätter och ', 'programmer ', '##ar larm - och säkerhets ##system hos nya kunder ', '[BGN] ', 'De ', 'utför ', 'även ', 'service och underhåll i befintliga kunders system ', 'Larm ', 'brand ', 'Larm ', 'ansluta larmet till kundernas nätverk ', 'för ', 'att öka bekvämlighet ##en och möjligheten att styra andra system ', 'Larm ', 'efter ']
# test idx:  41
# instance loss:  tensor(0.5410, grad_fn=<NllLossBackward>)
# ['att skapa bokning ']
# ['att ', 'jobba ', 'som sekreterare eller assistent på en marknads ##avdelning ', 'marknads ', '##assistenter ', 'som ', 'har en stor del eller hela ansvaret för marknadsföring ##en i ett företag eller i en organisation ', 'skapandet av ', 'reklam ', 'Exempelvis ', 'video , ', 'fotografier och ', 'inlägg på ', 'sociala medier ', 'administrativa ', 'att ', 'skapa bokning ##ar , ', 'event och förhandla om priser ']
# test idx:  42
# instance loss:  tensor(0.4422, grad_fn=<NllLossBackward>)
# ['genom att delta i material och sälj ']
# ['assistent ', 'projektledare ##n ', 'att ', 'stödja ', 'marknads ##ansvarig och ', 'produktchef med ', 'marknads ##relaterade uppgifter ', 'genom ', 'att delta i material och sälj ##present ##ationer ', 'ansvaret ', 'video , ', 'fotografier och ', 'inlägg på ', 'sociala ', 'Marknads ', 'att ', 'skapa presentation ##er och marknadsföra det egna eller andra företag ', 'genom ', 'sociala medier ', 'Marknads ', 'uppföljning av ']
# test idx:  43
# instance loss:  tensor(0.4104, grad_fn=<NllLossBackward>)
# ['att hålla kontakt , tillgodose önskemål och få in affärs ']
# ['skapa ', 'att ', 'följa tips på potentiella nya kunder ', 'Marknads ', 'bygga vidare på relationer med befintliga kunder ', 'genom ', 'att ', 'hålla kontakt , tillgodose önskemål och få in affärs ##information ', 'marknads ', 'med ', 'att ', 'stödja ', 'marknads ##ansvarig och ', 'produktchef ', 'med marknads ##relaterade uppgifter ', 'genom ', 'att delta i material och sälj ##present ##ationer ']
# test idx:  44
# instance loss:  tensor(0.5098, grad_fn=<NllLossBackward>)
# ['de som arbetar med att sköta olika slags maskiner i sågverk ']
# ['##opera ', '##t ', 'Såg ', '##verks ', '##opera ', '##t ', 'ett ', 'de ', 'som ', 'arbetar ', 'med att sköta olika slags maskiner i sågverk . ', '##opera ', '##t ', 'från ', 'ett operatör ', 'styr ', 'bark ##ningen eller ', 'sönder ##delningen av stock ##ar till plank och bräd ##or ', 'På ', 'TV - skärmar ', 'hela såg ##linjen ', 'följas ', 'övervakning ', 'av kritiska punkter ', 'ändra ', 'Som ', 'tork ', '##opera ', '##t ##ör eller ', 'tork ', '##tekniker ', 'planerar , ', 'styr och ', 'övervaka ', '##r den dator ##styrda tork ##ningen av virke i tork ##hus ##anläggningen ', 'justera ', 'temperatur ']
# test idx:  45
# instance loss:  tensor(0.4109, grad_fn=<NllLossBackward>)
# ['att ge lok ']
# ['Lok ', 'informerar sig ', 'om ', 'eventuella reparationer och hastighet ##sänd ##ringar längs banan ', 'Informationen ', 'bär ##bar fjärr ##styrning ', 'Lok ', '##föraren ', 'ansvarar ', 'för att tåget körs mjukt , säkert och i rätt hastighet ', 'teknisk ', 'arbetar ', 'med ', 'att ge lok ##förarna ', 'drift ##stöd när det uppstår tekniska problem på tåget ']
# test idx:  46
# instance loss:  tensor(0.4549, grad_fn=<NllLossBackward>)
# ['beskriver banan och de vägs ']
# ['på ', 'transport ##företag som ', 'transportera ##r passagerare eller gods ', 'trafik ', 'radio ', 'En ', 'så kallad ', 'linje ##bok ', 'beskriver banan och de vägs ##ignaler som finns längs sträckan ', 'att ', 'teknisk rådgivare ', 'arbetar ', 'med ', 'att ge lok ##förarna ', 'drift ##stöd när det uppstår tekniska problem på tåget ', 'Lok ', 'oregelbunden ']
# test idx:  47
# instance loss:  tensor(0.3196, grad_fn=<NllLossBackward>)
# ['specialister ']
# ['rek ', '##alm ', 'Vad ', 'för att projektet ska hålla tids ##planen ? ', 'Ekonomi ', 'administration ', 'planera ', 'Projekt ', '##ledaren ', 'ser till att projektet uppnår målen när det gäller tid ##plan , kvalitet och ekonomi ', 'en ', 'projekt ##grupp ', 'av ', 'specialister inom sina respektive områden ', 'ingenjörer , ', 'It - konsulter , ', 'inköpare och ', 'ekonomer ', 'personal ', '[UNK] nya ögon ']
# test idx:  48
# instance loss:  tensor(0.9778, grad_fn=<NllLossBackward>)
# ['om du uppgav en falsk identitet när du ansökte om uppehåll ']
# ['Uppehåll ', 'medborgare i Schweiz ', 'Efter ', 'fem år i Sverige ', 'ansöka ', 'om ', 'status som varaktigt bosatt i Sverige ', 'ha ', 'att ', 'om ', 'två år ', 'Migration ', 'återkall ', '##a ', 'Tillståndet ', 'återkall ', '##as ', 'om du ', 'uppgav ', 'en falsk identitet ', 'när du ansökte om uppehåll ##stillstånd , ', 'eller ', 'om du medvetet ljög eller inte berättade om något som hade betydelse för ditt uppehåll ##stillstånd ', 'Om ', 'Migration ##sverket ', 'avsl ', 'överklaga beslutet ', 'inom ', 'tre veckor från den dag då du fick beslutet ']
# test idx:  49
# instance loss:  tensor(0.5045, grad_fn=<NllLossBackward>)
# ['cirka en vecka ']
# ['att du har försörj ##t dig ', 'i ', 'fem år ', 'Efter ', 'beslut ', 'Beslutet ', 'skickas ', 'hem ', 'till din adress i Sverige ', '[BGN] ', 'När uppehåll ##stillstånd ', '##skort ##et är klart ', 'skickas ', 'det ', 'hem till dig ', 'inom ', 'cirka en vecka ', 'Migration ', '##sverket ', 'återkall ', '##a ', 'ett ', 'permanent tillstånd ', 'Ditt ', 'permanenta uppehåll ##stillstånd ', 'återkall ', 'om du flyttar från Sverige ']
# test idx:  50
# instance loss:  tensor(0.5253, grad_fn=<NllLossBackward>)
# ['cirka en vecka ']
# ['att alla uppgifter är if ##yllda och alla nödvändiga dokument finns med ', 'att handläggning ##stiden ', 'om allt som krävs finns med från början ', 'om ansökan kompletteras i efterhand ', 'så snart som möjligt efter det att du lämnat in din ansökan ', 'Migration ', 'ett år ', 'När uppehåll ##stillstånd ##skort ##et är klart ', 'skickas ', 'det hem till dig ', 'inom cirka en vecka ', 'lämnar ', 'in ', 'en ansökan om att förlänga ditt tillstånd ', 'Migration ', 'återkall ', 'ett tillstånd ', 'om ', 'uppgav ']
# test idx:  51
# instance loss:  tensor(0.2798, grad_fn=<NllLossBackward>)
# ['planerar de resor som företaget ska sälja ']
# ['Rese ', '##sälj ', '##are ', 'Rese ', '##sälj ', 'arbeta ', 'på en resebyrå ', 'hos en researrang ##ör ', 'hotell ', 'transporter ', 'kunskaper om ', 'viktigt ', 'att ', 'som ', 'reses ', 'vårda ', 'varumärket ', 'Bem ', 'Hos ', 'researrang ##örerna ', 'finns ', 'rese ', '##producenter ', 'som ', 'planerar de resor som företaget ska sälja ', 'De ', 'besöker ', 'nya resmål ', 'förhandlar ', 'skriver ', 'i ']
# test idx:  52
# instance loss:  tensor(0.5881, grad_fn=<NllLossBackward>)
# ['olje ']
# ['vid ', 'på ', 'sommar ', 'mer ', 'trafik längs kust ##erna ', 'jobbar ', 'kust ', '##bevak ', 'mer ', 'med ', 'att övervaka sjöt ##rafiken och skapa säkerhet på sjön . ', 'polis ', 'att övervaka nykterhet ', 'att göra kontroller så att yrkes ##fiskare följer de fisker ##egler som finns ', 'bland ', 'att fiskeb ##åtar ##nas fångst ##er och utrustning kontrolleras . ', 'kontroller av ', 'miljöskydd ', 'att man ', 'gör ', 'utryck ##ningar vid kris ##situation ##er till havs såsom ', 'olje ##utsläpp ']
# test idx:  53
# instance loss:  tensor(0.4608, grad_fn=<NllLossBackward>)
# ['att övervaka nykterhet till sjöss ']
# ['Kust ', 'på ', '25 kust ##stationerna ', 'vid ', 'på ', 'kust ', '##bevak ', 'att ', 'ha ', 'ett ', 'beredskap ##sarbete ', 'det ', 'att arbetet varierar ', 'från ', 'lugna rutin ##sy ##ssl ##or till ', 'akuta situationer ', 'vid ', 'sjör ##ädd ##ning , ', 'sjukt ##ransporter eller olje ##utsläpp ', 'Den ', 'dagliga rutin ##en ', 'när ', 'avbrytas ', 'av ', 'larm . ', 'att övervaka sjöt ##rafiken och skapa säkerhet på sjön ', 'polis ', 'att övervaka nykterhet till ', 'att utreda och rapportera misstänkta brott som ', 'narkotika ##smugg ##ling ']
# test idx:  54
# instance loss:  tensor(0.5265, grad_fn=<NllLossBackward>)
# ['intensivt ']
# ['Kust ', 'Kust ', '##bevakning ', 'arbetar ', 'på ', '25 kust ##stationerna som ', 'från Luleå i norr till Strömstad i väst , ', 'vid Vänern och Mälaren eller ', 'på den flyg ##station som finns för kust ##bevakning ##sflyg ##et ', 'kust ', 'årstid ', 'Under ', 'sommar ##halvåret ', 'då det är mer trafik längs kust ##erna ', 'intensivt ', 'jobbar ', 'kust ', '##bevak ', '##are ', 'mer ', 'med ', 'att övervaka sjöt ##rafiken och skapa säkerhet på sjön . ', 'polis ', 'att övervaka nykterhet till ', 'att utreda och rapportera misstänkta brott ', 'narkotika ##smugg ##ling ', 'att ']
# test idx:  55
# instance loss:  tensor(0.4706, grad_fn=<NllLossBackward>)
# ['124 ']
# ['Ansökan ', 'För ', 'betalar ', 'en avgift ', 'tydliga ', 'instruktioner ', 'om ', 'hur du fyller i din ansökan och ', 'vad du ska skicka med ', 'lätt ', 'att göra rätt ', 'ökar ', 'Ansökan om uppehåll ##stillstånd för egna företagare ', 'nummer ', '124 ', 'lämnar ', 'vid en svensk ambassad eller generalkonsul ##at i det land där du bor ']
# test idx:  56
# instance loss:  tensor(0.3158, grad_fn=<NllLossBackward>)
# ['att visa bilen ']
# ['Bil ', '##försäljare ', 'bil ', '##försäljare ', 'arbeta ', 'på ', 'små ', 'En ', 'del ', 'säljer ', 'enbart ', 'nya personbilar av ett visst varumärke ', 'begagnade ', 'i ', 'Bil ', '##försäljare ', 'uppsök ', 'med ', 'att visa bilen och låta kunden provkör ##a den ', 'Om kunden ', 'förhandlingen ', 'om ']
# test idx:  57
# instance loss:  tensor(0.8408, grad_fn=<NllLossBackward>)
# ['bil ']
# ['på små ', 'att ', 'förhandlingen ', 'om priset ', 'Oavsett ', 'om det är ', 'en ny eller begagnad bil ', 'vill ', 'kunden ', 'prut ', '##a på priset ', 'Vid ', 'utl ##ämning av bilen ', 'gör ', 'ofta ', 'bil ##försäljare ##n ', 'en genomgång av bilen . ', 'Vid ', 'försäljning till företag ', 'bil ', '##försäljare ', '##n ', 'som ', 'söker upp företagen och ', 'diskuterar företagets behov av tjänstebil ##ar ', 'att ', 'erbjuda ', 'kompletta finansierings ##program för fordon till företag ', 'bil ', 'leasing ##verksamhet ', 'bil ##uth ##yrning under lång tid till privatpersoner och företag ', 'Bil ', 'göra ', 'en värdering av ', 'inbyte ##sbilar ', 'om kunden vill få ']
# test idx:  58
# instance loss:  tensor(0.5009, grad_fn=<NllLossBackward>)
# ['fakta om bilarna de säljer ']
# ['säljer ', 'lyssna ', 'bil ', '##försäljare ', 'kunna ', 'en hel del ', 'fakta om bilarna de säljer ', 'vilja ', 'veta ', 'vilka ', 'hur ', 'att ', 'visa ', 'förhandlingen ', 'om priset ', 'Oavsett ', 'om det är ', 'en ny eller begagnad bil ', 'vill ', 'kunden ', 'prut ', '##a på priset ', 'utl ', 'bil ', 'en ', 'bil ', 'leasing ##verksamhet ', 'bil ##uth ##yrning under lång tid till privatpersoner och företag ', 'Bil ', 'göra ', 'en värdering av ', 'inbyte ##sbilar ', 'om kunden vill få hjälp med att sälja ']
# test idx:  59
# instance loss:  tensor(0.5524, grad_fn=<NllLossBackward>)
# ['visningar av flygplatsen ']
# ['korta bytes ##tider ', 'att leverera ', 'tar ', 'inc ##he ##ck ##ning till ', 'mat ', 'inom ', 'flygplatser ', '##itor ', 'service ', 'som ', 'anordnar ', 'studiebesök och visningar av flygplatsen ', 'Trafik ', 'passagerare från världens alla hörn ', 'svara ', 'På små flygplatser ', 'trafik ##assistenten ', 'utföra ']
# test idx:  60
# instance loss:  tensor(0.6174, grad_fn=<NllLossBackward>)
# ['forskning ']
# ['Mont ', 'montera ', 'sätter samman generat ##orer , motorer och transform ##atorer ', 'De ', 'skruvar , ', 'löd ', '##er , ', 'justera ', '##r och ', 'kontrollerar ', 'De ', 'plockar ihop de komponenter som ska finnas med och ', 'sätter säk ##ringar , ', 'bryta ##re och övriga delar på plats ', 'i ', 'ren ', 'mikroskop ', 'Ren ##rum ', 'en miljö där tillverkning eller vetenskaplig forskning bedrivs och som har en kontrollerad nivå av föroreningar ) ', 'i ']
# test idx:  61
# instance loss:  tensor(0.3645, grad_fn=<NllLossBackward>)
# ['läsa ritningar ']
# ['krets ', 'Då ', 'placerar ', 'man ut och ', 'löd ##er fast elektroniska komponenter på krets ##kort . ', '[BGN] ', 'två ', 'metoder ', 'hål ##mont ', '##ering och ', 'yt ##mont ##ering ', 'Vid ', 'yt ', 'plockas ', 'datorer ', 'i ', 'Alla i gruppen ', 'måste ', 'kunna ', 'läsa ritningar och arbets ##instrukt ##ioner ', 'dagtid ']
# test idx:  62
# instance loss:  tensor(0.1121, grad_fn=<NllLossBackward>)
# ['att ha en kompetent person som tackar ja och börjar ']
# ['Rekry ', '##terar ', '##e ', 'Rekry ', '##terar ', 'Rekry ', '##terar ', 'att ', 'stödja rekryterings ##processen när en ', 'fackliga ', 'är ', 'att ha en kompetent person som tackar ja och börjar . ']
# test idx:  63
# instance loss:  tensor(0.4973, grad_fn=<NllLossBackward>)
# ['rekrytera ']
# ['från ', 'ansvarig chef ', 'Rekry ', 'gör ', 'en överenskommelse med uppdragsgivare ##n om ', 'vad ', 'Rekry ', 'arbetar ', 'efter den ', 'När ett uppdrag kommit ', 'tar ', 'rekryterings ##konsult ##en ', 'fram ', 'en krav ##profil ', 'genom ', 'att aktivt lyssna och ställa frågor ', 'till ', 'vetenskapliga ', 'Första ', 'urvalet ', 'görs ', 'via ', 'förint ', '##erv ##ju ##er ', 'av ', 'rekrytera ##ren själv som ', 'väljer ut de lämpliga ##ste ']
# test idx:  64
# instance loss:  tensor(0.2164, grad_fn=<NllLossBackward>)
# ['förint ']
# ['Rekry ', '##terings ', 'kunna ', 'sälja ', 'Första ', 'urvalet ', 'via ', 'förint ', '##erv ', '##ju ', '##er ', 'av ', 'rekrytera ##ren själv som ', 'väljer ut de lämpliga ##ste ']
# test idx:  65
# instance loss:  tensor(0.5891, grad_fn=<NllLossBackward>)
# ['lämpliga kandidater ']
# ['att ', 'till chef ', 'för ', 'att kunna förstå organisationens behov ', 'Krav ##profilen ', 'ska ', 'sedan ', 'matcha ##s ', 'mot ', 'lämpliga kandidater ', 'tar ', 'rekrytera ', 'av ', 'en ', 'rese ##arch ##er som söker ', 'i ', 'söker ', 'rekrytera ', 'matcha ', 'utbildning och erfarenhet mot krav ##profilen ', 'Därefter ', 'matcha ', '##s ', 'personliga egenskaper ', 'mot krav ##profilen ', 'tester ', 'bygger ', 'på ', 'vetenskapliga metoder ', 'Rekry ', '##terar ', '##en ', 'går ', 'sedan ', 'igenom och ', 'analyserar kandidaterna ##s kompetens mot krav ##profilen ', 'förint ', '##erv ']
# test idx:  66
# instance loss:  tensor(0.2714, grad_fn=<NllLossBackward>)
# ['hur man får pengarna att räcka till ']
# ['Arbetsuppgifter ', 'Hem ', 'matlagning ', 'Hem ', 'undervisar ', 'i ', 'konsument ##ekonomi ', '- ', 'hur man får pengarna att räcka till och ', 'vilka rättigheter man har som konsument ', 'att ', 'köpa in de varor som ']
# test idx:  67
# instance loss:  tensor(0.5062, grad_fn=<NllLossBackward>)
# ['forskning och forskar ']
# ['universitets - och högskole ', 'att utveckla pedagogik ##en och planera utbildningen ', 'Universitet ', '##s - och högskole ', '##lärare ', 'handled ', '##er studenterna i deras arbete och deras studier ska bedömas och exam ##iner ##as ', '[BGN] ', 'Lek ', '##tor ', '##er ', 'har ', 'vanligtvis ', 'avlagt doktors ##examen . ', 'vid en högskola eller ett universitet ', 'En ', 'professor ', 'är ', 'ansvarig för forskning och forskar ##utbildning inom sitt ämne . ']
# test idx:  68
# instance loss:  tensor(0.3146, grad_fn=<NllLossBackward>)
# ['till din folkbok ']
# ['ansöka ', 'att du behöver skydd ', 'tillfälligt ', 'familjemedlem till någon som har fått uppehåll ##stillstånd av skydds ##skäl ', 'asyl ', 'Ansök ', 'på ', 'tre månader innan ', 'Migration ', '##sverket ', 'skickar ', 'koden ', 'till din folkbok ##föring ##sad ##ress ', 'meddela ', 'om ']
# test idx:  69
# instance loss:  tensor(0.3000, grad_fn=<NllLossBackward>)
# ['tre veckor från den dag beslutet meddelades ']
# ['att ', 'planera för att ', 'inom den tid som står i beslutet ', 'Ett beslut om avslag ', 'gäller ', 'i ', 'fyra år ', 'I ', 'hur lång tid du har på dig att överklaga ', 'tre veckor från den dag beslutet meddelades ', 'planera ']
# test idx:  70
# instance loss:  tensor(0.4404, grad_fn=<NllLossBackward>)
# ['att du måste lämna landet ']
# ['Om ', 'avslag ', 'Om ', 'Migration ', 'avsl ', 'att du inte har rätt till uppehåll ##stillstånd i Sverige och ', 'att du måste lämna landet om du befinner dig här ', 'planera för att återvända till ditt hemland eller ', 'när du måste lämna Sverige ', 'hur lång tid du ', 'inom ', 'fyra veckor ', 'tre ', 'inom den tid som står i beslutet ', 'Ett beslut om avslag ', 'gäller ', 'i ', 'fyra år ', 'Av ', '##visning ']
# test idx:  71
# instance loss:  tensor(0.4797, grad_fn=<NllLossBackward>)
# ['arbete på kvällar , nätter och helger ']
# ['Install ', 'Styr ', 'Kontroll ', 'Ta ', 'fram ', 'teknisk dokumentation ', 'Plan ', '##era ', 'investeringar ', 'Projekt ', '##leda ', 'utvecklings - och förändring ##sarbeten ', 'Sam ', '##la in och analysera mät ##värden ', 'att utveckla nya tekniska lösningar inom industriell automat ##ion ', 'förbättring av ', 'Bered ', '##skap ', '##stjänst ', 'jour ', 'arbete på kvällar , nätter och helger ']
# test idx:  72
# instance loss:  tensor(0.6038, grad_fn=<NllLossBackward>)
# ['automat ']
# ['Install ', 'Kontroll ', 'Ta ', 'fram ', 'teknisk dokumentation och man ##ual ##er ', 'Plan ', '##era ', 'investeringar ', 'Projekt ', '##leda ', 'utvecklings - och förändring ##sarbeten ', 'Sam ', '##la in och analysera mät ', 'att utveckla nya tekniska lösningar inom industriell automat ##ion ', 'förbättring ', 'Resor både inom och utanför Sverige ', 'Bered ', '##skap ', 'jour ']
# test idx:  73
# instance loss:  tensor(0.3932, grad_fn=<NllLossBackward>)
# ['automat ']
# ['inom ', 'automat ##ions ##ingenjör ', 'automat ', 'Install ', 'Kontroll ', 'Ta ', 'fram ', 'teknisk dokumentation och man ##ual ##er ', 'Plan ', '##era investeringar ', 'Projekt ', '##leda utvecklings - och förändring ##sarbeten ', 'Sam ', 'Autom ', '##ations ', '##tekniker ', 'har ', 'en ', 'arbetsledande eller ', 'projekt ##ledande roll ', 'Arbets ']
# test idx:  74
# instance loss:  tensor(0.6442, grad_fn=<NllLossBackward>)
# ['ansvarar för att nya IT ']
# ['på större företag , i organisationer eller ', 'på myndigheter ', 'att företagen använder IT - systemen på det mest effektiva sättet ', 'flera typer ', 'IT - ', 'arkitekter ', 'utan ', 'skarpa gränser emellan ', '[BGN] ', 'Yrkes ', '##ti ', '##tl ', 'variera ', 'mellan ', 'olika arbetsplatser ', 'ansvarar ', 'för att nya IT - tjänster åter ##använd ##er tidigare funktioner och ', 'att de följer riktlinjer som företaget satt upp för den tekniska arkitektur ##en ', 'Lös ', 'stora ']
# test idx:  75
# instance loss:  tensor(0.4613, grad_fn=<NllLossBackward>)
# ['utför beräkningar och kvalitets ']
# ['Brygger ', '##iar ', '##bet ', '##are ', 'arbetar ', 'på ', 'bryggeri ##er som tillverkar ', 'öl och andra drycker som ', 'läsked ##rycker , ', 'mineral ##vatten och ', 'juice ', 'övervakning ', 'i kontroll ##rummet ', 'livsmedels ', 'för ', 'den som har ', 'samordna ##nd ##e uppgifter , ', 'utför ', 'beräkningar och kvalitets - och produkt ##kontroller inom livsmedels ##industrin ', '[BGN] ', 'Process ', '##operativ ', '##t arbete ', 'inom ', 'industri ##bag ##erier ', 'beskrivning ', 'Bag ', '##are . ']
# test idx:  76
# instance loss:  tensor(0.7078, grad_fn=<NllLossBackward>)
# ['pra ']
# ['Maskin ', 'övervaka ', '##r och ', 'kontrollerar tillverknings ##processen ', 'via ', 'en datas ##kär ##m i ett kontroll ##rum ', 'också ', 'inställning ##ar i produktionen ', 'justeras ', 'operatör ', 'ha ', 'kunskap om ', 'vad som händer med livs ##medlet i processen ', 'Brygger ', '##iar ', '##bet ', '##are ', 'arbetar ', 'på ', 'bryggeri ##er som tillverkar öl och andra drycker som ', 'läsked ##rycker , ', 'mineral ##vatten och ', 'juice . ', 'övervakning ', 'i kontroll ##rummet och ', 'ute i bryggeri ##et ', 'Cho ', '##kla ', '##d ', 'i ', 'produktions ##linjer ', 'godis ', 'pra ##line ##r , ', 'choklad ##kakor eller ', 'skum / gel ##é ', 'I ', 'tillsätts ', 'råvaror ']
# test idx:  77
# instance loss:  tensor(0.6125, grad_fn=<NllLossBackward>)
# ['att analysera och tolka manus ']
# ['scen ', '##ografen ', 'om ', 'att ', 'analysera och tolka ', 'manus för att skapa en vision om scenografi ##n ', 'Scen ', 'hjälpa ', 'tekniska ', 'dator ', 'hantverkare ', 'Scen ', '##ografen ', 'arbetsled ', '##er ', 'följer ', 'hantverk ##arnas arbete ', 'i verkstäder och ateljé ##er ', 'med ', 'att ', 'snick ##ra och måla kuliss ##er , ', 'sy upp kostymer med ', 'Scen ', '##ografen ', 'ett ', 'nära samarbete ', 'med ', 'rekvis ##it ##ören ', 'införs ##ka ##ffar ', 'inrednings ##detaljer , ', 'möbler och andra föremål ', 'stor ', 'ansvarar ']
# test idx:  78
# instance loss:  tensor(0.5201, grad_fn=<NllLossBackward>)
# ['ansvarar för att rekvis ']
# ['dator ', 'hantverkare ', 'Scen ', '##ografen ', 'arbetsled ', '##er och ', 'följer hantverk ##arnas arbete ', 'i verkstäder och ateljé ##er ', 'med ', 'att ', 'snick ##ra och måla kuliss ##er , sy upp kostymer med mera ', 'Scen ', '##ografen ', 'ett ', 'nära samarbete ', 'med ', 'rekvis ##it ##ören ', 'införs ##ka ##ffar ', 'inrednings ##detaljer , ', 'möbler och andra föremål ', 'Rek ', '##visit ', '##ören ', 'har ', 'stor produkt ##kunskap ', 'ansvarar för att rekvis ##ita ##n håller hög kvalitet ', 'hämtas ', 'från ']
# test idx:  79
# instance loss:  tensor(0.2085, grad_fn=<NllLossBackward>)
# ['i Juk ']
# ['Arbetsuppgifter ', 'hotell ##boende ', 'kultur ##tur ', 'allt ', 'exempelvis ', 'i ', 'Ystad omkring ', 'fenomenet Kurt Wallander eller ', 'Ish ##otell ##et i Juk ##kas ##järvi ', 'säsong ']
# test idx:  80
# instance loss:  tensor(0.5889, grad_fn=<NllLossBackward>)
# ['en modell ']
# ['i ', 'stora serier ', 'till ', 'många människor ', 'En ', 'industri ', '##design ', '##er ', 'vara ', 'specialiserad ', 'på ', 'ett material , ', 'en viss typ av tjänster , ', 'en slut ##produkt eller en tillverknings ##process ', 'verktyg ', 'tred ', 'tekniska beskrivningar och mått ', 'I ', 'en modell av produkten , ', 'en så kallad prot ##otyp ', 'gör ', 'prot ##otyper ', 'av ', 'hur man upplever situationen i banken , ', 'på myndigheten eller under resan ', 'Industri ', '##design ', 'behöver ', 'ta ', 'ställning ', 'när ', 'Hur ']
# test idx:  81
# instance loss:  tensor(0.5124, grad_fn=<NllLossBackward>)
# ['maskiner ']
# ['Industri ', '##design ', 'ett ', 'konstnärligt , ', 'tekniskt och marknads ##inriktat ', 'De ', 'arbetar ', 'med ', 'design av helt nya produkter / tjänster eller ', 'med ', 'vidareutveck ##ling av produkter / tjänster och idéer som finns på marknaden ', 'i ', 'stora ', 'Fys ', '##iska produkter ', 'verktyg , ', 'maskiner , fordon , telefoni eller ', 'hem ##elektronik ', 'bank ##ärenden , ', 'försäkringar , ', 'mötet med myndigheter ']
# test idx:  82
# instance loss:  tensor(0.9680, grad_fn=<NllLossBackward>)
# ['samhällsekonom ']
# ['På ', 'ekonomi ##avdelningar ', 'arbetar ', 'ekonomer ', 'med ', 'den ekonomiska styrningen , ', 'finansiering och marknadsföring ', 'redovisning , ', 'revision och sammanställning ##ar av budget ##ar ', 'vad sjukdomar och olycksfall kostar samhället . ', 'Hälso ', '##ekonom ', '##er ', 'arbetar ', 'i landsting , statliga myndigheter , försäkrings ##bolag eller till exempel läkemedels ##företag . ', 'Miljö ', '##ekonom ', 'analyserar ', 'hur man med ', 'Läns ##styrelse ##r , Naturvård ##sverket och Försvarsmakten ', 'National ', '##ekonom ', '##er ', 'gör ', 'samhällsekonom ##iska utredningar , ', 'analyser och prognoser ']
# test idx:  83
# instance loss:  tensor(0.4902, grad_fn=<NllLossBackward>)
# ['administration av löner ']
# ['Ekonom ', 'Ekonom ', '##er ', 'finns ', 'i ', 'alla branscher på arbetsmarknaden , såväl privata näringslivet , offentlig sektor och ideella organisationer ', 'en ', 'ekonom / civilekonom ', 'vid högskola eller universitet ', 'Eftersom ', 'ekonom ##yrken finns ', 'över hela arbetsmarknaden ', 'arbetsuppgifter ', 'variera ', 'ekonom ', 'gymnasie ##utbildning ', 'gymnasieekonom ##er ', 'administration av löner och ', 'handläggning av låne ##ansökningar ', 'Ekonom ', '##ekonom ', 'analyserar ']
# test idx:  84
# instance loss:  tensor(0.1233, grad_fn=<NllLossBackward>)
# ['förändra i sin verksamhet ']
# ['privatpersoner , ', 'företag eller ', 'organisationer ', 'Inom ', 'flera olika ', 'yrkes ##roller ', 'När lagen ändras ', 'företaget ', 'behöva ', 'förändra i sin verksamhet ', 'med ', 'när ']
# test idx:  85
# instance loss:  tensor(0.2680, grad_fn=<NllLossBackward>)
# ['utforma ']
# ['vilken specialisering ', 'Advokat ', 'företags ', 'bank ', 'varumärke ', 'förvaltnings ', 'Jurid ', '##iskt biträde ', 'ett ', 'samlings ', 'för ', 'en juridiskt utbildad person som företräder någon annan i en juridisk fråga ', 'De ', 'utforma ', '##r och ', 'tolkar avtal och kontrakt ', 'skriver ', 'föreskrifter och ']
# test idx:  86
# instance loss:  tensor(0.4141, grad_fn=<NllLossBackward>)
# ['att arbeta med olika ansikts ']
# ['Behandling ', 'att arbeta med olika ansikts ##behandling ##ar ', 'Hår ##växt ', 'avlägsna ##s ', 'tillfälligt ', 'med hjälp av ', 'vax ##ning . ', 'Ep ', '##iler ', '##ing ', 'en ', 'permanent hår ##bort ##tagning ##smetod ', 'där man ', 'med hjälp av ', 'ström ', 'tar död på de hår ##producerande ', 'En ', 'hud ', '##tera ##peut ', 'arbetar ', 'med ', 'inre välbefinnande ', 'avst ']
# test idx:  87
# instance loss:  tensor(0.7147, grad_fn=<NllLossBackward>)
# ['arbetar med att hålla rent i produktions ']
# ['vid sanering ##s - eller service ##företag som ', 'San ', '##erings ', 'många ', 'sanering ', 'As ', '##best ', '##san ', 'as ##best ', '##san ', '##erare ', 'gör ', 'besiktning ##ar och san ##erar as ##best från fastigheter , till exempel ', 'vid rivning ##sarbeten ', 'Brand ', '##skades ', '##aner ', 'brand ', '##skades ', '##aner ', 'begränsar skadorna efter bränder ', 'att suga upp släck ##nings ##vatten , sätta ut avf ##ukt ##nings ##aggregat och reng ##öra väggar , tak och inventarier ', '[BGN] ', '[UNK] ', 'Industri ', '##san ', '##ering ', 'industris ', '##aner ', '##are ', 'arbetar ', 'med att hålla rent i produktions ##anläggningar , ', 'fordons ##industrier , pappers ##bruk och raffina ##derier ', 'Kl ', '##otter ', 'klott ', '##ers ', '##aner ', 'skade ##djur ']
# test idx:  88
# instance loss:  tensor(0.4357, grad_fn=<NllLossBackward>)
# ['att golv ']
# ['lin ', 'vara jämnt ', 'att det ingår under ##arbete som exempelvis ', 'slip ##ning och spa ##ck ##ling i arbetet ', 'att slip ##a och yt ##behand ##la golv ', 'våt ##rum ', 'att golv ##läggare ##n klär golv och väggar med en vattent ##ät plast ##matta , ', 'i ett badrum ', 'hantverk ', 'skar ', 'svets ', 'knä ']
# test idx:  89
# instance loss:  tensor(0.4913, grad_fn=<NllLossBackward>)
# ...
# test idx:  264
# instance loss:  tensor(0.5360, grad_fn=<NllLossBackward>)
# ['Taxi ']
# ['prepar ', 'vid ', 'Brig ##ham Young University Life Science ##s Museum ', 'Taxi ', '##der ##mi ', '[UNK] gestaltning av huden [UNK] ', 'konsten ', 'att konserver ##a döda ryggrad ##sdjur ', 'uppst ##opp ##ning av ', 'prepar ', '##ering ', 'Taxi ', '##der ', 'att prepar ##era ett ryggrad ##sdjur så att det bevaras för efter ##världen ', 'der ##mo ##plast ', 'der ##ma ', 'hud ', 'Malm ##ska ', 'Histor ', 'Taxi ', '##der ##mi ', 'i och med ', 'utvecklingen av tekniken att prepar ##era ( gar ##va ) djur ##hud ##ar ', 'uppst ', 'ett mjukt material ']
# test idx:  265
# instance loss:  tensor(0.2480, grad_fn=<NllLossBackward>)
# []
# ['fix ', 'cyklar ', 'mot slutet ', 'cykelb ', 'Så ', '##klart ', 'är ', 'cykeln ', 'främsta objekt till ', 'dyrk ##an ', 'fix ##ie . ', 'cykelb ##ud ', 'en så kallad ', '[BGN] ', 'All ', '##ey ##cat , ', 'en sorts ', 'cykel ##orientering i stads ##trafik , ofta ', 'natt ##id . ', 'Europa ']
# test idx:  266
# instance loss:  tensor(0.3550, grad_fn=<NllLossBackward>)
# ['Cri ']
# ['fix ', 'cyklar ', 'mot slutet ', 'cykelb ##ud ', 'Så ', '##klart ', 'är ', 'cykeln ', 'främsta objekt till ', 'dyrk ##an ', 'fix ##ie . ', 'cykelb ', 'All ', 'All ##ey ', 'cykel ##orientering på bana , tra ##cks ##tan ##d ( balans ##tävling ) , skid ( sladd ) , ', 'cykelb ##rottning , cykel ##pol ##o eller vad som helst som värd ##staden kan hitta på ', 'cykelb ##ud ', 'Cri ', '##ti ', '##cal mass . ', 'i de flesta städer ']
# test idx:  267
# instance loss:  tensor(0.3290, grad_fn=<NllLossBackward>)
# []
# ['Cykel ##bud ', 'Ett ', 'cykelb ##ud ', 'en ', 'transport ##arbetare på cykel . ', 'en cykel ', 'fix ', 'i ', 'en stor ryggsäck ', 'de ', 'använder ', 'större transport ##cyklar med ', 'fla ##k ', 'Sedan ', 'cyklar började ', 'mass ', 'mot slutet av 1800 - talet ', 'Cri ', '##cal mass ', 'i ']
# test idx:  268
# instance loss:  tensor(0.3875, grad_fn=<NllLossBackward>)
# ['All ']
# ['fix ', 'i ', 'en stor ryggsäck ', 'de ', 'använder ', 'större transport ##cyklar ', 'med ', 'fla ##k ', 'via ', 'kom - radio ', 'med ', 'mobiltelefon ', 'Själv ', '##ständiga ', 'cykelb ##ud ', 'tar ', 'direkt emot order från kunden på ', 'mobiltelefon ', 'Sedan ', 'cyklar ', 'mot slutet av ', 'en ', '[BGN] ', 'All ', '##ey ##cat , ', 'en sorts ', 'cykel ##orientering i stads ##trafik , ', 'ofta ', 'natt ##id ', 'Europa - och världsmäst ##erska ', 'varje ', 'i ']
# test idx:  269
# instance loss:  tensor(0.1983, grad_fn=<NllLossBackward>)
# ['marknadsföring ']
# ['en ', 'Historia ', '[END] ', 'Sedan ', 'cyklar ', 'mass ', 'mot slutet av 1800 - talet ', 'använts ', 'för ', 'att transportera mindre gods ', 'cykeln ', 'snabbare transporter ', 'marknadsföring ', 'klimat ##hotet ', 'skapat ', 'ett sug efter miljövän ##liga tjänster ']
# test idx:  270
# instance loss:  tensor(0.3530, grad_fn=<NllLossBackward>)
# ['att företag efterfråg ']
# ['fix ', 'cyklar ', 'mot slutet av 1800 ', 'Den ', 'att cykeln är det i särklass snabbaste fordonet i stads ##trafik ', 'att många meddelanden som transportera ##ts av cykelb ##ud tagits över av dessa ', 'Cykel ##bud ', 'ser ', 'positivt på framtiden ', 'en stor marknad av ', 'mindre gods och ', 'original ##dokument som inte kan ', 'digital ##iseras ', 'Allt ', 'snabbare flöde ##n av information ', 'att företag efterfråg ##ar ', 'snabbare transporter ', 'klimat ']
# test idx:  271
# instance loss:  tensor(0.3812, grad_fn=<NllLossBackward>)
# ['positivt ']
# ['Cykel ##bud ', 'Ett ', 'cykelb ##ud ', 'är ', 'en ', 'transport ##arbetare på cykel . ', 'en cykel ', 'Sedan ', 'cyklar började ', 'mass ##produc ##eras ', 'mot slutet av 1800 - talet ', 'har ', 'för ', 'att transportera mindre gods ', 'Efter ', 'att nästan ', 'utk ', 'bilen ', 'cykeln ', 'transport ##fordon ', 'av ', 'att cykeln ', 'det i särklass snabbaste ', 'att många meddelanden som transportera ##ts av cykelb ##ud tagits över av dessa ', 'Cykel ##bud ', 'ser dock ', 'positivt på framtiden ']
# test idx:  272
# instance loss:  tensor(0.4665, grad_fn=<NllLossBackward>)
# ['Internet via bredband ']
# ['bud ##firman ', 'De ', 'arbetar ', 'mest ', 'som ', 'egen ##företagare och underl ##ever ##ant ##örer ', 'Sedan ', 'cyklar ', 'mass ', 'mot slutet av 1800 - talet ', 'för ', 'att transportera mindre gods ', 'Efter ', 'att nästan ', 'utk ', 'bilen ', 'cykeln ', 'transport ##fordon ', 'av ', 'att cykeln ', 'det i särklass snabbaste fordonet i stads ##trafik ', 'under 1970 - talets oljek ##ris ', 'i större städer ', 'Upp ', '##komsten av nya kommunikations ##medel ', 'Internet via bredband i synnerhet ', 'betytt ', 'att många meddelanden som transportera ##ts av cykelb ##ud tagits över av dessa ']
# test idx:  273
# instance loss:  tensor(0.2374, grad_fn=<NllLossBackward>)
# ['Cykel ']
# ['[BGN] ', 'Cykel ', '##bud ', 'Ett ', 'cykelb ##ud ', 'en ', 'transport ', 'en ', 'mobiltelefon ', 'Cykel ##n ', 'I ', 'mo ', 'dubb ', 'fix ', 'i ', 'de ', 'använder ', 'större transport ##cyklar med ', 'fla ##k ', 'cykelb ', 'Sedan ', 'cyklar ', 'mass ', 'mot slutet av ']
# test idx:  274
# instance loss:  tensor(0.1902, grad_fn=<NllLossBackward>)
# ['mot slutet av 1800 ']
# ['en ', 'cykelb ', 'för ', 'en ', 'tar emot order och delar ut bud ', 'Sedan ', 'cyklar ', 'mass ', 'mot slutet av 1800 - talet ', 'för ', 'att transportera mindre gods ', 'cykeln ']
# test idx:  275
# instance loss:  tensor(0.3648, grad_fn=<NllLossBackward>)
# ['med mobiltelefon ']
# ['en ', 'Kommunikation ', 'via ', 'kom - radio ', 'med ', 'mobiltelefon ', 'tar ', 'direkt ', 'en ', 'att ', 'cykelb ##ud är anställda av bud ##firman ', 'som ', 'egen ##företagare och ', 'underl ', 'Sedan ', 'cyklar ', 'mot slutet av 1800 - talet ', 'för att transportera mindre gods ', 'Efter ', 'att ', 'bilen ', 'cykeln ', 'transport ##fordon ', 'att cykeln ', 'det i särklass snabbaste fordonet i stads ##trafik ']
# test idx:  276
# instance loss:  tensor(0.3021, grad_fn=<NllLossBackward>)
# ['med dubb ']
# ['Cykel ##bud ', 'Ett ', 'cykelb ##ud ', 'en ', 'transport ##arbetare på cykel . ', 'en cykel ', 'I Sverige ', 'mo ##untain ##bi ##ke utrustade med ', 'dubb ##däck ', 'under vintern . ', 'Heltid ', 'fix ', 'bud ', 'Historia ', 'Sedan ', 'cyklar började ', 'mass ##produc ##eras ', 'mot slutet av 1800 - talet , ', 'har ', 'för ', 'att transportera mindre gods ']
# test idx:  277
# instance loss:  tensor(0.4282, grad_fn=<NllLossBackward>)
# ['en cykel , stor ryggsäck och kom ']
# ['Cykel ', 'cykelb ##ud ', 'en ', 'transport ##arbetare på cykel . ', 'en cykel , ', 'stor ryggsäck och ', 'kom ##radio eller ', 'mobiltelefon ', 'Själv ', '##ständiga ', 'cykelb ##ud ', 'tar ', 'direkt emot order från kunden på mobiltelefon ', 'Sedan ', 'cyklar ', 'mot slutet av 1800 - talet ', 'i större städer ', 'Upp ', '##komsten av ', 'nya kommunikations ##medel ', 'Internet via bredband i synnerhet ', 'betytt ', 'att många meddelanden som transportera ##ts av cykelb ##ud tagits över av dessa ']
# test idx:  278
# instance loss:  tensor(0.3814, grad_fn=<NllLossBackward>)
# []
# ['Els ', '##äkerhet ', '##sverket ', 'har ', 'ställt ', 'en rad ', 'krav på ', 'vilket innehåll och längd utbildning ska innehålla ', 'för godkännas vid ansökan ', 'godkänd ', 'rätt ', 'Med ', 'eli ##ns ##tal ##lat ##ör ', 'en person som av Els ##äkerhet ##sverket eller tidigare myndigheter tilldelats behörighet att utföra eli ##ns ##tal ##lat ##ions ##arbete i angiven omfattning ', 'Mont ']
# test idx:  279
# instance loss:  tensor(0.2440, grad_fn=<NllLossBackward>)
# []
# ['behörighet ', 'Beh ', '##ör ', '##igheter ', 'för ', 'några olika typer av arbeten och spänning ##snivåer ', '[BGN] ', 'En eli ##ns ##tal ##lat ##ör ', 'har ', 'ett behörighet ##sbevis som visar på dennes behörighet ']
# test idx:  280
# instance loss:  tensor(0.3660, grad_fn=<NllLossBackward>)
# []
# ['behörighet ', 'Beh ', '##ör ', '##igheter ', 'för ', 'några olika typer av arbeten och spänning ##snivåer ', 'ett behörighet ', 'se till att anläggningen som installation ##sarbetet omfattar har kontrollerat ##s i betryggande omfattning innan det tas i bruk ', 'Mont ']
# test idx:  281
# instance loss:  tensor(0.2112, grad_fn=<NllLossBackward>)
# []
# ['Elekt ', 'En ', 'elektriker ', 'en hantverkare som ', 'framförallt ', 'arbetar ', 'med installation och service av elektriska anläggningar ', 'En elektriker ', 'i ', 'film - och tv - inspelning ', 'som ', 'ljuss ', '##ättar ##e ', 'att man arbetar helt utan behörighet ', 'Els ', '##äkerhet ']
# test idx:  282
# instance loss:  tensor(0.2804, grad_fn=<NllLossBackward>)
# []
# ['på gymnasiet ', 'hos privata utbildnings ##företag samt ', 'på universitet ', 'När ', 'Beh ', '##ör ', '##igheter ', 'Vem som får utföra eli ##ns ##tal ##lat ##ions ##arbete ', 'reglera ##t ', 'i ', 'regeringens föreskrifter , ', '( ', '1990 : ', '80 ##6 ) ', 'Elin ', '##stall ']
# test idx:  283
# instance loss:  tensor(0.4572, grad_fn=<NllLossBackward>)
# []
# ['hos ', 'i ', 'regeringens föreskrifter ', '1990 : 80 ##6 ', 'Elin ', '##stall ##ations ##arbete som avser elektrisk stark ##ströms ##anläggning ', 'Yrkes ', 'anställda i samma organisation , ', 'Med ', 'eli ##ns ##tal ##lat ##ör ', 'en person som av Els ##äkerhet ##sverket eller tidigare myndigheter tilldelats behörighet att utföra eli ##ns ##tal ##lat ##ions ##arbete i angiven omfattning ', 'Mont ']
# test idx:  284
# instance loss:  tensor(1.0794, grad_fn=<NllLossBackward>)
# ['Under slutet av 1800 ']
# ['med att arrangera och sälja ', 'kostnads ##kalk ##yler ', 'arbets ', 'vatten ##av ##visande förkl ##äde med fickor där arbets ##redskap kan förvaras ', 'i ', 'inom ', 'gymnasieskolan ', 'från 182 ##7 ', 'en söndags ##skola för flor ##ister ', '" ', 'fle ##uri ', '[BGN] ', 'Svenska Slöjd ##skolan ', 'gav ', 'tidigt ', 'kurser i detta hantverk . ', '[END] ', 'Amal ##ia Fredrika Lindström ', 'gick ', 'sex terminer ', 'på Slöjd ##skolan och ', 'fick ', '1875 ', 'stipendium för ', 'tre års studier i Paris . ', 'Under slutet av 1800 - talet ', 'en rad välkända flor ##ister ', 'i Stockholm , ', 'Emma Heb ##be , Ida Hag ##lind och Hild ##ur Carlsson ']
# test idx:  285
# instance loss:  tensor(0.7083, grad_fn=<NllLossBackward>)
# ['Emilia F ']
# ['Arbetet ', 'flor ##ist ', 'praktiskt inriktat ', 'teoretiska kunskaper inom ', 'färg / form - lära , ', 'försäljning samt exponering av varor ', 'flor ', 'med ', 'att sätta samman kalkyler för ', 'kostnads ##kalk ', 'vatten ', 'inom ', 'i ', 'gav ', 'Kungliga Tekniska Högskolan ', 'från 182 ##7 ', 'en söndags ##skola för ', 'flor ##ister ', '" ', 'fle ##uri ##ster " ', 'flor ##ister ', 'i Sverige ', 'Emilia F ##ür ##sten ##hoff och Carolina Fredrika Ram ##stedt , ', 'sex ', 'tre ']
# test idx:  286
# instance loss:  tensor(0.9760, grad_fn=<NllLossBackward>)
# ['" ']
# ['arbetar ', 'en ', 'flor ##ist ', 'med ', 'att sätta samman kalkyler för både butiken som helhet ', 'med ', 'kostnads ##kalk ##yler för de enskilda flor ##istiska arbetena som ska försälj ##as ', 'vatten ##av ##visande förkl ##äde med fickor där arbets ##redskap kan förvaras ', 'flor ', 'i Sverige ', 'inom gymnasieskolan ##s Hantverk ##sprogram ', 'fristående utbildningar ', 'Historia ', 'i Sverige ', 'gav ', 'Kungliga Tekniska Högskolan ', 'från 182 ##7 ', 'en söndags ##skola för ', 'flor ##ister , ', '" ', 'fle ##uri ##ster " ', 'flor ', 'i Sverige ', 'Emilia F ##ür ##sten ##hoff och Carolina Fredrika Ram ##stedt ']
# test idx:  287
# instance loss:  tensor(0.7702, grad_fn=<NllLossBackward>)
# ['vatten ']
# ['Arbetet ', 'flor ##ist ', 'praktiskt inriktat ', 'teoretiska kunskaper inom ', 'färg / form - lära , ', 'försäljning samt exponering av varor ', 'arbetar ', 'en ', 'flor ##ist ', 'med ', 'att sätta samman kalkyler för både butiken som helhet ', 'med ', 'kostnads ##kalk ##yler för de enskilda flor ##istiska arbetena som ska försälj ##as ', 'Lämplig ', 'arbets ##kläd ', 'vatten ##av ##visande förkl ##äde med fickor där arbets ##redskap kan förvaras ', 'flor ', 'i Sverige ', 'inom gymnasieskolan ##s Hantverk ##sprogram ', 'Kungliga Tekniska ', 'fle ##uri ']
# test idx:  288
# instance loss:  tensor(0.6059, grad_fn=<NllLossBackward>)
# ['inom blomster ']
# ['[BGN] ', 'Flor ', '##ist ', 'En ', 'flor ##ist ', 'arbetar ', 'med ', 'att arrangera och sälja kruk ##växter och snitt ##blommor ', 'Flor ', '##ister ', 'anställda ', 'inom blomster ##handeln eller ', 'på handels ##trädgård ##ar ', 'Historia ', 'i ', 'gav ', 'Kungliga Tekniska Högskolan ', 'från 182 ##7 ', 'en söndags ##skola för ', 'flor ##ister ', '" ', 'fle ##uri ##ster " ', 'Emilia F ##ür ##sten ##hoff och Carolina Fredrika Ram ##stedt ']
# test idx:  289
# instance loss:  tensor(0.5035, grad_fn=<NllLossBackward>)
# ['Handeln ']
# ['riktlinjer ', 'Kommun ', '80 K ', 'Entrepren ', 'Studier ', 'bedrivas ', 'under ', '1 alternativt 2 terminer ', 'Hantverk ', 'en ', '3 - årig gymnasie ##utbildning ', 'att gå som dekor ##atör ##sele ##v ', 'handels ', 'yrkes ##ut ', 'Butik ', '##skommun ', '##ikat ##ör / ', 'mer ##chan ##dis ##er ', 'tex ', 'Kate ##dra ##ls ##kol ##an i Skara ', '[BGN] ', 'Handeln ', '##s försäljning och konjunktur ##er ', 'avgör ', 'ofta ', 'hur stort behovet eller viljan är ', 'att anställa dekor ##atörer ']
# test idx:  290
# instance loss:  tensor(0.4420, grad_fn=<NllLossBackward>)
# ['en 3 ']
# ['riktlinjer ', 'av skylt ', 'Kommun ', '80 K ', 'Entrepren ', 'Studier ', 'bedrivas ', 'under ', '1 alternativt 2 terminer ', '[BGN] ', 'Hantverk ', '##sprogrammet ', 'ger ', 'en ', '3 - årig gymnasie ##utbildning inom inredning , både hem och butik . ', 'I ', 'vissa fall ', 'fortfarande ', 'utbilda sig till ', 'dekor ##atör ', 'genom ', 'att gå som ', 'dekor ##atör ##sele ##v ']
# test idx:  291
# instance loss:  tensor(0.3392, grad_fn=<NllLossBackward>)
# ['att man missar mycket regler : livsmedels ']
# ['att säkerställa hygien ##krav ##en och beställa ', 'att ', 'vispa grädde , baka anslag ', 'tårt ##bott ', 'vid ', 'klockan 4 [UNK] ', 'det lättaste ', 'att man missar mycket regler : ', 'livsmedels ##hygien / fakta och dessutom ofta bara får en smal syn på yrket som gäller för just det konditori man prakt ##iserar på ', 'avläg ', '##ga ', 'prov för ', 'ges ##äll - och mäster ##brev ']
# test idx:  292
# instance loss:  tensor(0.5404, grad_fn=<NllLossBackward>)
# ['Livsmedel ']
# ['sockerb ', 'att ', 'vispa grädde , baka anslag ', 'tårt ##bott ##nar ', 'att se till att kunderna har färska bak ##verk från butiken ##s öppning ', 'Den ', 'konditor i Sverige ', 'gå ', 'Livsmedel ##sprogrammet i gymnasieskolan ', 'olika ', 'lokala ', 'utbildnings ##inriktning ', 'mot ', 'bageri och konditori ', 'på ', 'ett antal olika orter i Sverige ', 'Lär ', '##lings ', 'att ']
# test idx:  293
# instance loss:  tensor(0.7701, grad_fn=<NllLossBackward>)
# ['för att se till att kunderna har färska bak ']
# ['sockerb ', 'att ', 'vispa grädde , baka anslag ( ', 'tårt ##bott ##nar ', 'lägga ihop tårt ##or ', 'På ', 'ett lokalt bageri ', 'börjar ', 'arbetsdag ##en ', 'vid tidig morgon ( ', 'klockan 4 [UNK] 5 ', 'för ', 'att se till att kunderna har färska bak ##verk från butiken ##s öppning ', 'konditor i Sverige ', 'gå ', 'Livsmedel ##sprogrammet i gymnasieskolan . ', 'olika lokala utbildnings ##inriktning ', 'mot ', 'bageri och konditori ', 'på ', 'ett antal olika orter i Sverige ', 'Lär ', '##lings ', 'att man missar mycket regler ', 'livsmedels ##hygien / fakta ']
# test idx:  294
# instance loss:  tensor(0.6019, grad_fn=<NllLossBackward>)
# ['vid tidig morgon ( klockan 4 [UNK] 5 är inte ovanligt ) ']
# ['sockerb ', 'att ', 'vispa grädde , ', 'tårt ##bott ##nar ', 'På ', 'ett lokalt bageri ', 'börjar ', 'arbetsdag ##en ', 'vid tidig morgon ( ', 'klockan 4 [UNK] 5 ', 'för ', 'att se till att kunderna har färska bak ##verk från butiken ##s öppning . ', '[BGN] ', 'konditor i Sverige ', 'gå ', 'Livsmedel ##sprogrammet i gymnasieskolan ', 'att man missar mycket regler ', 'livsmedels ##hygien / fakta ']
# precision:  0.0455478252164773
# recall:  0.840258541089566
